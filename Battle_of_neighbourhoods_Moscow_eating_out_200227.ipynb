# %% [markdown]
# <b>1. Load libraries

# %%
#!conda config --add channels conda-forge

import requests # library to handle requests
import pandas as pd # library for data analsysis

# !conda install geopandas
import geopandas as gpd

import json

#!conda install shapely
#from shapely.geometry import shape, Point

#!conda install -c conda-forge geopy --yes 
#from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

 
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - geopandas
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     libdap4-3.19.1             |       h6ec2957_0         1.5 MB
#     json-c-0.13.1              |       h1bed415_0          70 KB
#     gdal-2.3.3                 |   py36hbb2a789_0         1.3 MB
#     shapely-1.6.4              |   py36h86c5351_0         330 KB
#     xerces-c-3.2.2             |       h780794e_0         3.2 MB
#     giflib-5.1.4               |       h14c3975_1          78 KB
#     libspatialite-4.3.0a       |      hb08deb6_19         3.1 MB
#     libgdal-2.3.3              |       h2e7e64b_0        17.7 MB
#     geopandas-0.6.1            |             py_0         911 KB
#     click-plugins-1.1.1        |             py_0          11 KB
#     kealib-1.4.7               |       hd0c454d_6         175 KB
#     libkml-1.3.0               |       h590aaf7_4         633 KB
#     poppler-0.65.0             |       h581218d_1         1.6 MB
#     libspatialindex-1.9.3      |       he6710b0_0         3.1 MB
#     geos-3.7.1                 |       he6710b0_0         1.6 MB
#     munch-2.5.0                |             py_0          16 KB
#     poppler-data-0.4.9         |                0         3.5 MB
#     hdf4-4.2.13                |       h3ca952b_2         916 KB
#     openssl-1.1.1d             |       h7b6447c_4         3.7 MB
#     ca-certificates-2020.1.1   |                0         132 KB
#     freexl-1.0.5               |       h14c3975_0          44 KB
#     openjpeg-2.3.0             |       h05c96fa_1         456 KB
#     rtree-0.9.3                |           py36_0          47 KB
#     pyproj-1.9.6               |   py36h14380d9_0          76 KB
#     fiona-1.8.4                |   py36hc38cc03_0         1.0 MB
#     proj4-5.2.0                |       he6710b0_1         7.0 MB
#     cligj-0.5.0                |           py36_0          12 KB
#     libnetcdf-4.6.1            |       h11d0813_2         1.3 MB
#     ------------------------------------------------------------
#                                            Total:        53.7 MB
#
# The following NEW packages will be INSTALLED:
#
#     click-plugins:   1.1.1-py_0
#     cligj:           0.5.0-py36_0
#     fiona:           1.8.4-py36hc38cc03_0
#     freexl:          1.0.5-h14c3975_0
#     gdal:            2.3.3-py36hbb2a789_0
#     geopandas:       0.6.1-py_0
#     geos:            3.7.1-he6710b0_0
#     giflib:          5.1.4-h14c3975_1
#     hdf4:            4.2.13-h3ca952b_2
#     json-c:          0.13.1-h1bed415_0
#     kealib:          1.4.7-hd0c454d_6
#     libdap4:         3.19.1-h6ec2957_0
#     libgdal:         2.3.3-h2e7e64b_0
#     libkml:          1.3.0-h590aaf7_4
#     libnetcdf:       4.6.1-h11d0813_2
#     libspatialindex: 1.9.3-he6710b0_0
#     libspatialite:   4.3.0a-hb08deb6_19
#     munch:           2.5.0-py_0
#     openjpeg:        2.3.0-h05c96fa_1
#     poppler:         0.65.0-h581218d_1
#     poppler-data:    0.4.9-0
#     proj4:           5.2.0-he6710b0_1
#     pyproj:          1.9.6-py36h14380d9_0
#     rtree:           0.9.3-py36_0
#     shapely:         1.6.4-py36h86c5351_0
#     xerces-c:        3.2.2-h780794e_0
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2019.11.27-0         --> 2020.1.1-0
#     openssl:         1.1.1d-h7b6447c_3    --> 1.1.1d-h7b6447c_4
#
#
# Downloading and Extracting Packages
# libdap4-3.19.1       | 1.5 MB    | ##################################### | 100%
# json-c-0.13.1        | 70 KB     | ##################################### | 100%
# gdal-2.3.3           | 1.3 MB    | ##################################### | 100%
# shapely-1.6.4        | 330 KB    | ##################################### | 100%
# xerces-c-3.2.2       | 3.2 MB    | ##################################### | 100%
# giflib-5.1.4         | 78 KB     | ##################################### | 100%
# libspatialite-4.3.0a | 3.1 MB    | ##################################### | 100%
# libgdal-2.3.3        | 17.7 MB   | ##################################### | 100%
# geopandas-0.6.1      | 911 KB    | ##################################### | 100%
# click-plugins-1.1.1  | 11 KB     | ##################################### | 100%
# kealib-1.4.7         | 175 KB    | ##################################### | 100%
# libkml-1.3.0         | 633 KB    | ##################################### | 100%
# poppler-0.65.0       | 1.6 MB    | ##################################### | 100%
# libspatialindex-1.9. | 3.1 MB    | ##################################### | 100%
# geos-3.7.1           | 1.6 MB    | ##################################### | 100%
# munch-2.5.0          | 16 KB     | ##################################### | 100%
# poppler-data-0.4.9   | 3.5 MB    | ##################################### | 100%
# hdf4-4.2.13          | 916 KB    | ##################################### | 100%
# openssl-1.1.1d       | 3.7 MB    | ##################################### | 100%
# ca-certificates-2020 | 132 KB    | ##################################### | 100%
# freexl-1.0.5         | 44 KB     | ##################################### | 100%
# openjpeg-2.3.0       | 456 KB    | ##################################### | 100%
# rtree-0.9.3          | 47 KB     | ##################################### | 100%
# pyproj-1.9.6         | 76 KB     | ##################################### | 100%
# fiona-1.8.4          | 1.0 MB    | ##################################### | 100%
# proj4-5.2.0          | 7.0 MB    | ##################################### | 100%
# cligj-0.5.0          | 12 KB     | ##################################### | 100%
# libnetcdf-4.6.1      | 1.3 MB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     openssl-1.1.1d             |       h516909a_0         2.1 MB  conda-forge
#     ca-certificates-2019.11.28 |       hecc5488_0         145 KB  conda-forge
#     branca-0.4.0               |             py_0          26 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     certifi-2019.11.28         |           py36_0         149 KB  conda-forge
#     altair-4.0.1               |             py_0         575 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.0 MB
#
# The following NEW packages will be INSTALLED:
#
#     altair:          4.0.1-py_0        conda-forge
#     branca:          0.4.0-py_0        conda-forge
#     folium:          0.5.0-py_0        conda-forge
#     vincent:         0.4.4-py_1        conda-forge
#
# The following packages will be UPDATED:
#
#     certifi:         2019.11.28-py36_0             --> 2019.11.28-py36_0     conda-forge
#
# The following packages will be DOWNGRADED:
#
#     ca-certificates: 2020.1.1-0                    --> 2019.11.28-hecc5488_0 conda-forge
#     openssl:         1.1.1d-h7b6447c_4             --> 1.1.1d-h516909a_0     conda-forge
#
#
# Downloading and Extracting Packages
# openssl-1.1.1d       | 2.1 MB    | ##################################### | 100%
# ca-certificates-2019 | 145 KB    | ##################################### | 100%
# branca-0.4.0         | 26 KB     | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# certifi-2019.11.28   | 149 KB    | ##################################### | 100%
# altair-4.0.1         | 575 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Folium installed
# Libraries imported.

# %% [markdown]
# <b> 2. Load Moscow districts data (geojson)</b>

# %%
url = 'http://gis-lab.info/data/mos-adm/ao.geojson'

gdf = gpd.read_file(url)

df = pd.DataFrame(gdf.iloc[:,:-1].values, columns = list(gdf.columns.values)[:-1] )

# %%
gdf = gdf.drop([gdf.columns[1], gdf.columns[2]], axis='columns')
gdf.head()
# Out:
#              NAME                                           geometry
# 0        Троицкий  MULTIPOLYGON (((36.80310 55.44083, 36.80319 55...
# 1  Новомосковский  MULTIPOLYGON (((37.08697 55.59036, 37.09492 55...
# 2  Зеленоградский  POLYGON ((37.13160 56.01645, 37.13266 56.01678...
# 3    Юго-Западный  POLYGON ((37.45572 55.63705, 37.46372 55.64070...
# 4   Юго-Восточный  MULTIPOLYGON (((37.66069 55.73070, 37.66082 55...

# %%
df['name_length'] = df['NAME'].str.len()
df.sort_values('name_length', ascending=False, inplace=True)
df.head(12)
# Out:
#                 NAME     OKATO          ABBREV  name_length
# 8   Северо-Восточный  45280000            СВАО           16
# 7    Северо-Западный  45283000            СЗАО           15
# 1     Новомосковский  45297000  Новомосковский           14
# 2     Зеленоградский  45272000           ЗелАО           14
# 4      Юго-Восточный  45290000            ЮВАО           13
# 3       Юго-Западный  45293000            ЮЗАО           12
# 5        Центральный  45286000             ЦАО           11
# 10         Восточный  45263000             ВАО            9
# 0           Троицкий  45298000        Троицкий            8
# 6           Северный  45277000             САО            8
# 11          Западный  45268000             ЗАО            8
# 9              Южный  45296000             ЮАО            5

# %% [markdown]
# <b> 3. Load restaurants/cafes data for Moscow</b>

# %%
url = 'https://raw.githubusercontent.com/RunnerTony/CoureraProjectsRepo/master/moscow_eatout_json_utf8.txt'

results = requests.get(url).json()

df_cafes = json_normalize(results)
#df_cafes=pd.read_json'https://raw.githubusercontent.com/RunnerTony/CoureraProjectsRepo/master/moscow_eatout_json', encoding='WINDOWS-1251')
df_cafes.head()
# Out:
#                                              Address  \
# 0         город Москва, улица Егора Абакумова, дом 9
# 1  город Москва, улица Талалихина, дом 2/1, корпус 1
# 2          город Москва, Абельмановская улица, дом 6
# 3  город Москва, Абрамцевская улица, дом 9, корпус 1
# 4              город Москва, Угличская улица, дом 17
#
#                                    AdmArea           District         ID  \
# 0  Северо-Восточный административный округ  Ярославский район   00151635
# 1       Центральный административный округ    Таганский район  000077874
# 2       Центральный административный округ    Таганский район  000024309
# 3  Северо-Восточный административный округ    район Лианозово   00119365
# 4  Северо-Восточный административный округ    район Лианозово  000027429
#
#   IsNetObject       Latitude_WGS84      Longitude_WGS84  \
# 0         нет  55.8790015313033730  37.7145650004360390
# 1         нет  55.7382386551547000  37.6733061300344000
# 2         нет  55.7355114718314000  37.6696475969381000
# 3         нет  55.9040863698490400  37.5723061316711200
# 4         нет  55.9040188006692200  37.5669400000000020
#
#                                                 Name OperatingCompany  \
# 0                                            СМЕТАНА              NaN
# 1                                             Родник              NaN
# 2                                    Кафе «Академия»              NaN
# 3                             Кафе «Вишневая метель»              NaN
# 4  ГБОУ «Школа № 1430 имени Героя Социалистическо...              NaN
#
#                             PublicPhone  SeatsCount SocialPrivileges  \
# 0  [{'PublicPhone': '(499) 183-14-10'}]          48              нет
# 1  [{'PublicPhone': '(495) 676-55-35'}]          35              нет
# 2  [{'PublicPhone': '(495) 662-30-10'}]          95              нет
# 3  [{'PublicPhone': '(499) 200-00-22'}]          50              нет
# 4  [{'PublicPhone': '(499) 908-06-15'}]         240              нет
#
#   TypeObject                     geoData.coordinates geoData.type  global_id
# 0       кафе  [37.71456500043604, 55.87900153130337]        Point  637376221
# 1       кафе    [37.6733061300344, 55.7382386551547]        Point  637376331
# 2       кафе    [37.6696475969381, 55.7355114718314]        Point  637376349
# 3       кафе  [37.57230613167112, 55.90408636984904]        Point  637376403
# 4   столовая           [37.56694, 55.90401880066922]        Point  637376480

# %%
df_cafes.shape
# Out:
# (16299, 16)

# %%
df_cafes['TypeObject'].value_counts()
# Out:
# кафе                                 6464
# столовая                             2439
# ресторан                             2318
# предприятие быстрого обслуживания    2181
# бар                                  1000
# буфет                                 574
# кафетерий                             553
# закусочная                            434
# магазин (отдел кулинарии)             336
# Name: TypeObject, dtype: int64

# %%
df_cafes = df_cafes[df_cafes.SeatsCount != 0]
df_cafes.shape
# Out:
# (14266, 16)

# %%
df_cafes['TypeObject'].value_counts()
# Out:
# кафе                                 6052
# столовая                             2418
# ресторан                             2277
# предприятие быстрого обслуживания    1291
# бар                                   964
# буфет                                 489
# кафетерий                             412
# закусочная                            211
# магазин (отдел кулинарии)             152
# Name: TypeObject, dtype: int64

# %% [markdown]
# <b> 4. Aggregate seats count data the dataframe (df) </b>

# %%
df_tmp = df_cafes
Scount = []
print('Seats count by district:')
for distr in df['NAME'].values:
    df2 = df_tmp[df_tmp['AdmArea'].str.contains(distr)]
    df_tmp = df_tmp[df_tmp['AdmArea'].str.contains(distr)==False]
    s = df2['SeatsCount'].sum()
    print(distr,': ', s)
    Scount.append(s)
    
df['SeatsCount']=Scount
# Out:
# Seats count by district:
# Троицкий :  6901
# Новомосковский :  17075
# Зеленоградский :  17159
# Юго-Западный :  66151
# Юго-Восточный :  65867
# Центральный :  245833
# Северный :  72842
# Северо-Западный :  44228
# Северо-Восточный :  90083
# Южный :  103701
# Восточный :  74862
# Западный :  91702

# %%
df.head()
# Out:
#              NAME     OKATO          ABBREV  SeatsCount
# 0        Троицкий  45298000        Троицкий        6901
# 1  Новомосковский  45297000  Новомосковский       17075
# 2  Зеленоградский  45272000           ЗелАО       17159
# 3    Юго-Западный  45293000            ЮЗАО       66151
# 4   Юго-Восточный  45290000            ЮВАО       65867

# %% [markdown]
# <b>5. Load population by district and merge that into the dataframe (df)</b>

# %%
df_pop=pd.read_csv("https://raw.githubusercontent.com/RunnerTony/CoureraProjectsRepo/master/moscow_population_v2.csv", encoding='WINDOWS-1251')
df_pop.shape
# Out:
# (176, 4)

# %%
df_pop['name_length'] = df_pop['Муниципальное образование'].str.len()
df_pop.sort_values('name_length', ascending=False, inplace=True)
df_pop.head()
# Out:
#                              Муниципальное образование Все население  \
# 60   в том числе муниципальные образования Северо-В...           NaN
# 79   в том числе муниципальные образования Северо-З...           NaN
# 147  в том числе муниципальные образования Новомоск...           NaN
# 35   в том числе муниципальные образования Зеленогр...           NaN
# 101  в том числе муниципальные образования Юго-Вост...           NaN
#
#     в т.ч. городское в т.ч. сельское  name_length
# 60               NaN             NaN           63
# 79               NaN             NaN           62
# 147              NaN             NaN           61
# 35               NaN             NaN           61
# 101              NaN             NaN           60

# %%
df_tmp = df_pop
Pcount = []
print('Population by district:')
for distr in df['NAME'].values:
    df2 = df_tmp[df_tmp['Муниципальное образование'].str.contains(distr)]
    df_tmp = df_tmp[df_tmp['Муниципальное образование'].str.contains(distr)==False]
    s = df2['Все население'].sum()
    print(distr,': ', s)
    Pcount.append(s)
    
df['Population']=Pcount
df.head()
# Out:
# Population by district:
# Троицкий :  108 063
# Новомосковский :  183 591
# Зеленоградский :  232 489
# Юго-Западный :  1 414 510
# Юго-Восточный :  1 363 859
# Центральный :  760 690
# Северный :  1 151 160
# Северо-Западный :  979 614
# Северо-Восточный :  1 402 928
# Южный :  1 760 813
# Восточный :  1 495 835
# Западный :  1 344 044
#              NAME     OKATO          ABBREV  SeatsCount Population
# 0        Троицкий  45298000        Троицкий        6901    108 063
# 1  Новомосковский  45297000  Новомосковский       17075    183 591
# 2  Зеленоградский  45272000           ЗелАО       17159    232 489
# 3    Юго-Западный  45293000            ЮЗАО       66151  1 414 510
# 4   Юго-Восточный  45290000            ЮВАО       65867  1 363 859

# %%
#df['Saturation']=df['SeatsCount']/df['Population']
#df.head()
#if type(df['Population'].values[1]) == object:
#    df['Population'] = df['Population'].str.replace(' ','')
#    df['Population']=pd.to_numeric(df['Population'])

df['Population'] = df['Population'].str.replace(' ','')
df['Population']=pd.to_numeric(df['Population'])    
df['Saturation']=1000*df['SeatsCount']/df['Population']
df.head()
# Out:
#              NAME     OKATO          ABBREV  SeatsCount  Population  \
# 0        Троицкий  45298000        Троицкий        6901      108063
# 1  Новомосковский  45297000  Новомосковский       17075      183591
# 2  Зеленоградский  45272000           ЗелАО       17159      232489
# 3    Юго-Западный  45293000            ЮЗАО       66151     1414510
# 4   Юго-Восточный  45290000            ЮВАО       65867     1363859
#
#    Saturation
# 0   63.860896
# 1   93.005648
# 2   73.805642
# 3   46.766018
# 4   48.294582

# %%
df_data=df.drop([df.columns[1], df.columns[2], df.columns[3], df.columns[4]], axis='columns')

df_data.head()
# Out:
#              NAME  Saturation
# 0        Троицкий   63.860896
# 1  Новомосковский   93.005648
# 2  Зеленоградский   73.805642
# 3    Юго-Западный   46.766018
# 4   Юго-Восточный   48.294582

# %% [markdown]
# <b> 6. Create a "heat map" of districts based on seat counts data (folium choropleth map)</b>

# %%
#let's see the most saturated (in terms of seats per '000 persons) districts:
df_data.sort_values('Saturation', ascending=False, inplace=True)
df_data.head(12)
# Out:
#                 NAME  Saturation
# 5        Центральный  323.171068
# 1     Новомосковский   93.005648
# 2     Зеленоградский   73.805642
# 11          Западный   68.228421
# 8   Северо-Восточный   64.210708
# 0           Троицкий   63.860896
# 6           Северный   63.277042
# 9              Южный   58.893818
# 10         Восточный   50.046964
# 4      Юго-Восточный   48.294582
# 3       Юго-Западный   46.766018
# 7    Северо-Западный   45.148395

# %%
#the Central district (row id=5) seems like an outlier, so let's "switch off" this one for the sake of visualization that followws
df_data.at[5,'Saturation'] = 0
df_data.head(12)
# Out:
#                 NAME  Saturation
# 5        Центральный    0.000000
# 1     Новомосковский   93.005648
# 2     Зеленоградский   73.805642
# 11          Западный   68.228421
# 8   Северо-Восточный   64.210708
# 0           Троицкий   63.860896
# 6           Северный   63.277042
# 9              Южный   58.893818
# 10         Восточный   50.046964
# 4      Юго-Восточный   48.294582
# 3       Юго-Западный   46.766018
# 7    Северо-Западный   45.148395

# %%
seats_map = folium.Map(location=[55.709, 37.627], zoom_start=10)

seats_map.choropleth(geo_data=gdf, name='choropleth', data=df_data, columns=['NAME', 'Saturation'], key_on='feature.properties.NAME', fill_color='YlGn', fill_opacity=0.7, line_opacity=0.2, legend_name='Saturation (seats per 1000 persons)')
folium.LayerControl().add_to(seats_map)

seats_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
